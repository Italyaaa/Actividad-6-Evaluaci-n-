# %%
import Funciones as fs
import pandas as pd

# %%
#Carga los archivos con extensiones .csv y .xlsx y los convierte a dataframe, si es un  archivo con 
# cualquier otra extensión, emitirá el raise (“Este formato no esta soportado para esta función: .formato”)
data = fs.Funcion_1('Estocolmo.csv')
data = data.drop(['Unnamed: 0'], axis=1) #Si es necesario poner 0 en filas
data
# Out:
#      last_scraped  host_since  host_response_time host_response_rate  \
# 0      2024-12-30  2011-07-06      within an hour               100%
# 1      2024-12-30  2011-02-27        within a day               100%
# 2      2024-12-30  2011-10-05  within a few hours               100%
# 3      2024-12-30  2011-07-06      within an hour               100%
# 4      2024-12-30  2011-11-22  within a few hours               100%
# ...           ...         ...                 ...                ...
# 5218   2024-12-30  2014-11-16                 NaN                NaN
# 5219   2024-12-30  2021-10-04                 NaN                NaN
# 5220   2024-12-30  2021-02-23                 NaN                NaN
# 5221   2024-12-30  2013-05-09                 NaN                NaN
# 5222   2024-12-30  2024-12-28                 NaN                NaN
#
#      host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                    100%                 t                    2
# ...

# %%
#Sustituye los valores nulos de las variables pares numéricas con el método “mean” y de las impares 
#numéricas con la constante “99”. Las columnas que no sean de tipo numérico se sustituirán con el 
#string “Este_es_un_valor_nulo”
data = fs.Funcion_2(data)
pd.options.display.max_columns = None
data
# Out:
#       host_listings_count  host_total_listings_count  latitude  longitude  \
# 0                       2                          2  59.31389   18.06087
# 1                       2                          4  59.33351   18.03693
# 2                       1                          1  59.33872   18.05131
# 3                       2                          2  59.31198   18.06076
# 4                       3                          3  59.30543   18.10771
# ...                   ...                        ...       ...        ...
# 5218                    2                          2  59.35677   18.08598
# 5219                    1                          1  59.29383   18.09755
# 5220                    2                          3  59.25325   18.07406
# 5221                    1                          1  59.26996   17.96409
# 5222                    1                          1  59.36694   17.92118
#
#       accommodates  bathrooms  bedrooms  beds  minimum_nights  maximum_nights  \
# ...

# %%
#Identifica los valores nulos “por columna” y “por dataframe”
data = fs.Funcion_3(data)
data
# Out:
# ('Valores nulos por columna',
#  host_listings_count                                0
#  host_total_listings_count                          0
#  latitude                                           0
#  longitude                                          0
#  accommodates                                       0
#  bathrooms                                          0
#  bedrooms                                           0
#  beds                                               0
#  minimum_nights                                     0
#  maximum_nights                                     0
#  minimum_minimum_nights                             0
#  maximum_minimum_nights                             0
#  minimum_maximum_nights                             0
#  maximum_maximum_nights                             0
#  availability_30                                    0
#  availability_60                                    0
#  availability_90                                    0
# ...

# %%
#Sustituye  los valores atípicos de las columnas numéricas con el método de “Rango intercuartílico”
data = fs.Funcion_4(data)
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Sustituye  los valores atípicos de las columnas numéricas con el método de “Rango intercuartílico”
# ----> 2 data = fs.Funcion_4(data)
#       3 data
#
# File c:\Users\italy\Downloads\Clase alfredo\Evaluación\Funciones.py:62, in Funcion_4(data)
#      60 def Funcion_4(data):
#      61     import pandas as pd
# ---> 62     df_result = data.copy()
#      63     columnas_numericas = df_result.select_dtypes(include='number').columns
#      65     for columna in columnas_numericas:
#      66         # Calcular Q1, Q3 y el rango intercuartílico (IQR)
#
# AttributeError: 'tuple' object has no attribute 'copy'
